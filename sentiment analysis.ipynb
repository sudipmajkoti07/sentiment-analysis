# %%
# Install the required package
# !pip install spacy

# Download the spaCy language model
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (70.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (70.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sudip\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Import necessary libraries
import spacy
from spacy.tokens import DocBin
from spacy.util import minibatch, compounding
from sklearn.model_selection import train_test_split
import random

# Load spaCy's pre-trained English model
nlp = spacy.blank("en")

# Add the TextCategorizer to the pipeline
textcat = nlp.add_pipe("textcat", config={"exclusive_classes": True, "architecture": "simple_cnn"})

# Add labels to the TextCategorizer
textcat.add_label("POSITIVE")
textcat.add_label("NEGATIVE")
textcat.add_label("NEUTRAL")
# Out:
# ---------------------------------------------------------------------------
# ConfigValidationError                     Traceback (most recent call last)
# Cell In[6], line 12
#       9 nlp = spacy.blank("en")
#      11 # Add the TextCategorizer to the pipeline
# ---> 12 textcat = nlp.add_pipe("textcat", config={"exclusive_classes": True, "architecture": "simple_cnn"})
#      14 # Add labels to the TextCategorizer
#      15 textcat.add_label("POSITIVE")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\language.py:821, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     817     pipe_component, factory_name = self.create_pipe_from_source(
#     818         factory_name, source, name=name
#     819     )
#     820 else:
# --> 821     pipe_component = self.create_pipe(
#     822         factory_name,
#     823         name=name,
#     824         config=config,
#     825         raw_config=raw_config,
#     826         validate=validate,
#     827     )
#     828 pipe_index = self._get_pipe_index(before, after, first, last)
#     829 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\language.py:709, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     706 cfg = {factory_name: config}
#     707 # We're calling the internal _fill here to avoid constructing the
#     708 # registered functions twice
# --> 709 resolved = registry.resolve(cfg, validate=validate)
#     710 filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     711 filled = Config(filled)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\confection\__init__.py:760, in registry.resolve(cls, config, schema, overrides, validate)
#     751 @classmethod
#     752 def resolve(
#     753     cls,
#    (...)
#     758     validate: bool = True,
#     759 ) -> Dict[str, Any]:
# --> 760     resolved, _ = cls._make(
#     761         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     762     )
#     763     return resolved
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\confection\__init__.py:809, in registry._make(cls, config, schema, overrides, resolve, validate)
#     807 if not is_interpolated:
#     808     config = Config(orig_config).interpolate()
# --> 809 filled, _, resolved = cls._fill(
#     810     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     811 )
#     812 filled = Config(filled, section_order=section_order)
#     813 # Check that overrides didn't include invalid properties not in config
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\confection\__init__.py:864, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     862     schema.__fields__[key] = copy_model_field(field, Any)
#     863 promise_schema = cls.make_promise_schema(value, resolve=resolve)
# --> 864 filled[key], validation[v_key], final[key] = cls._fill(
#     865     value,
#     866     promise_schema,
#     867     validate=validate,
#     868     resolve=resolve,
#     869     parent=key_parent,
#     870     overrides=overrides,
#     871 )
#     872 reg_name, func_name = cls.get_constructor(final[key])
#     873 args, kwargs = cls.parse_args(final[key])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\confection\__init__.py:939, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     937         result = schema.parse_obj(validation)
#     938     except ValidationError as e:
# --> 939         raise ConfigValidationError(
#     940             config=config, errors=e.errors(), parent=parent
#     941         ) from None
#     942 else:
#     943     # Same as parse_obj, but without validation
#     944     result = schema.construct(**validation)
#
# ConfigValidationError:
#
# Config validation error
# textcat -> architecture	extra fields not permitted
# textcat -> exclusive_classes	extra fields not permitted
# {'nlp': <spacy.lang.en.English object at 0x000001599E6ABCE0>, 'name': 'textcat', 'architecture': 'simple_cnn', 'exclusive_classes': True, 'model': {'@architectures': 'spacy.TextCatEnsemble.v2', 'linear_model': {'@architectures': 'spacy.TextCatBOW.v3', 'exclusive_classes': True, 'length': 262144, 'ngram_size': 1, 'no_output_layer': False}, 'tok2vec': {'@architectures': 'spacy.Tok2Vec.v2', 'embed': {'@architectures': 'spacy.MultiHashEmbed.v2', 'width': 64, 'rows': [2000, 2000, 500, 1000, 500], 'attrs': ['NORM', 'LOWER', 'PREFIX', 'SUFFIX', 'SHAPE'], 'include_static_vectors': False}, 'encode': {'@architectures': 'spacy.MaxoutWindowEncoder.v2', 'width': 64, 'window_size': 1, 'maxout_pieces': 3, 'depth': 2}}}, 'scorer': {'@scorers': 'spacy.textcat_scorer.v2'}, 'threshold': 0.0, '@factories': 'textcat'}

# %%
# Sample training data: list of tuples with text and sentiment label
data = [
    ("I love this!", {"cats": {"POSITIVE": 1.0}}),
    ("This is terrible.", {"cats": {"NEGATIVE": 1.0}}),
    ("I am indifferent about this.", {"cats": {"NEUTRAL": 1.0}}),
    ("I hate it so much!", {"cats": {"NEGATIVE": 1.0}}),
    ("This is the best thing ever!", {"cats": {"POSITIVE": 1.0}}),
    ("Not sure how I feel about this.", {"cats": {"NEUTRAL": 1.0}})
]

# Split the dataset into training and test sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
# Function to convert data to spaCy's DocBin format
def create_doc_bin(data):
    doc_bin = DocBin()
    for text, annotations in data:
        doc = nlp.make_doc(text)
        doc.cats = annotations["cats"]
        doc_bin.add(doc)
    return doc_bin

# Convert training and test data into DocBin format
train_docs = create_doc_bin(train_data)
test_docs = create_doc_bin(test_data)

# Training the model
n_iter = 10
optimizer = nlp.initialize()

for epoch in range(n_iter):
    random.shuffle(train_data)
    batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
    
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(texts, annotations, sgd=optimizer)

# Save the model
nlp.to_disk("sentiment_model")

# Load the saved model for inference
nlp = spacy.load("sentiment_model")

# Test the model on new examples
texts = ["I feel amazing today!", "I am not sure about this.", "This is terrible."]

for text in texts:
    doc = nlp(text)
    print(f"Text: {text} -> Sentiment: {doc.cats}")

# Evaluate model performance on test data
correct = 0
for text, annotations in test_data:
    doc = nlp(text)
    predicted = max(doc.cats, key=doc.cats.get)
    actual = max(annotations['cats'], key=annotations['cats'].get)
    print(f"Text: {text}, Predicted: {predicted}, Actual: {actual}")
    if predicted == actual:
        correct += 1

accuracy = correct / len(test_data)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
